# %% [markdown]
# # Selfie Project

# %% [markdown]
# This project for the Lede program 2021, should demonstrate what we learned this week in webscraping and html & Javascript.

# %% [markdown]
# ## Wikipedia page to scrape
#
# There were no readily available datasets to download for this topic, but I found a useful page on Wikipedia, where a lot of those accidents were recorded and with the latest data coming from 2021.
#
# Source: [List of selfie-related injuries and deaths](https://en.wikipedia.org/wiki/List_of_selfie-related_injuries_and_deaths)

# %% [markdown]
# ## Reading the web page into Python

# %%
# importing the necessary libraries 
import pandas as pd
import numpy as np
import requests
import matplotlib
from bs4 import BeautifulSoup

# %%
# fetch web page from the URL and store the result in a "response" object called r
# response object has a text attribute, which contains the same HTML code from our web browser

r = requests.get('https://en.wikipedia.org/wiki/List_of_selfie-related_injuries_and_deaths')

# %%
# print the first 500 characters of the HTML
print(r.text[0:500])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>List of selfie-related injuries and deaths - Wikipedia</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"1ae4ba33-e485

# %% [markdown]
# ### Parsing the HTML using Beautiful Soup

# %%
# parse the HTML (stored in r.text) into a special object called soup that the Beautiful Soup library understands
soup = BeautifulSoup(r.text, 'html.parser')

# %%
# finds the title tag
soup.title
# Out:
# <title>List of selfie-related injuries and deaths - Wikipedia</title>

# %%
# find how many table tags exist --> There are 2 tables on that page
len(soup.find_all('table'))
# Out:
# 2

# %% [markdown]
# ### Ask Beautiful Soup to find all of the records

# %%
# find where the data you want resides (in the table tag)
sp_table = soup.find_all('table')

# %%
# look at the 2 tables and find out which one has the needed data: table[0] 
#sp_table[0]

# %%
# save it as the new soup
sp_table = sp_table[0]

# %%
# find_all tr (table rows)

sp_trs = sp_table.find_all('tr')

# %%
# separate the first tr tag row for the header
sp_th = sp_trs[0].find_all('th')
sp_header = []
for th in sp_th:
    sp_header.append(th.text.strip())

# %%
sp_header
# Out:
# ['Date', 'Country', 'Injuries/Casualties', 'Type', 'Description', 'Source(s)']

# %%
# take a look at the html structure for on row in the table
sp_trs[1]
# Out:
# <tr>
# <td><span data-sort-value="000000002011-10-15-0000" style="white-space:nowrap">15 October 2011</span>
# </td>
# <td>United States
# </td>
# <td>3
# </td>
# <td>Transport
# </td>
# <td>Three teenagers (two sisters and a friend) were killed by a train while posing for a selfie that was found on their phone. Shortly before, they posted the message "Standing right by a train ahaha this is awesome!!!!" to <a href="/wiki/Facebook" title="Facebook">Facebook</a>.
# </td>
# <td><sup class="reference" id="cite_ref-8"><a href="#cite_note-8">[8]</a></sup><sup class="reference" id="cite_ref-9"><a href="#cite_note-9">[9]</a></sup>
# </td></tr>

# %%
# for each tr, find tds then for each td get text inside, then save to new array
sp_list = []
for tr in sp_trs[1:]:
    tds = tr.find_all('td')
    tr_list = []
    for (i, td) in enumerate(tds):
        # if it's the sixth column, get the citation number
        if(i == 5):
            # this temporary list is only created for each row, 
            # and only when we reach the sixth column
            temp_list = []
            for item in td.find_all('sup'):
                temp_list.append(item.get('id'))
            tr_list.append(temp_list)
        else:
            tr_list.append(td.text.strip())
    sp_list.append(tr_list)

# %% [markdown]
# ### Building the dataset

# %% [markdown]
# #### Creating a dataframe without the \n

# %%
# removing all the \n from the data header
# sp_header = [item.strip() for item in sp_header if str(item)]

# %%
# applying a tabular data structure using pandas

sp_df = pd.DataFrame(sp_list, columns=sp_header)
sp_df
# Out:
#                  Date        Country Injuries/Casualties           Type  \
# 0     15 October 2011  United States                   3      Transport
# 1          March 2014          Spain                   1  Electrocution
# 2          March 2014         Russia                   1      Transport
# 3          April 2014  United States                   1      Transport
# 4       22 April 2014         Russia                   1           Fall
# ..                ...            ...                 ...            ...
# 183   12 January 2020      Australia                   1           Fall
# 184     30 April 2020         Turkey                   1           Fall
# 185  12 December 2020      Australia                   1           Fall
# 186   12 January 2021       Slovenia                   1      Transport
# 187       16 May 2021      Indonesia                   9        Drowned
#
#                                            Description  \
# 0    Three teenagers (two sisters and a friend) wer...
# 1    A 21-year-old man was electrocuted after climb...
# 2    A train driver saw two people near the train t...
# 3    A 32-year-old woman from North Carolina was dr...
# 4    A 17-year-old girl fell 30 ft to her death aft...
# ..                                                 ...
# 183  A 21-year-old woman from Lincoln, England, fel...
# 184  A 31-year-old resident from Kazakhstan fell fr...
# 185  A 38-year-old woman from North Victoria fell 8...
# 186  A fatal accident in Maribor, Slovenia happened...
# 187  A boat overloaded with 20 people in a reservoi...
#
#                       Source(s)
# 0      [cite_ref-8, cite_ref-9]
# 1                 [cite_ref-10]
# 2                 [cite_ref-11]
# 3    [cite_ref-12, cite_ref-13]
# 4                 [cite_ref-14]
# ..                          ...
# 183              [cite_ref-218]
# 184              [cite_ref-219]
# 185              [cite_ref-220]
# 186              [cite_ref-221]
# 187              [cite_ref-222]
#
# [188 rows x 6 columns]

# %% [markdown]
# #### Converting the data types of the dataframe

# %%
# convert the date column to datetime format and overwrite the existing column
sp_df['Date'] = pd.to_datetime(sp_df['Date'])

# convert casualty numbers as integer
sp_df['Injuries/Casualties'] = sp_df['Injuries/Casualties'].astype(int)

# convert the text columns as strings
#sp_df[['Country', 'Type', 'Description']] = sp_df[['Country', 'Type', 'Description']].astype(str) --> does not work?? loc also not working
# sp_df['Country'] = sp_df['Country'].astype(str) does not remove the /n

# %%
# removing all the \n from the columns

# sp_df['Country']=sp_df['Country'].replace({'\n': ''}, regex=True)
# sp_df['Type']=sp_df['Type'].replace({'\n': ''}, regex=True)
# sp_df['Description']=sp_df['Description'].replace({'\n': ''}, regex=True)

# instead of citation number the whole html text will appear
# sp_df['Source(s)']=sp_df['Source(s)'].astype(str) 

# # sp_df['Source(s)'] = [foo.get('id') for foo in sp_df['Source(s)']]
# for index, row in sp_df.iterrows():
#     sources = row['Source(s)']
#     for source in sources:
#         print(source.get('id'))

# %% [markdown]
# ## Find all the corresponding links (work in progress)

# %%
links = soup.find_all('li', id=lambda x: x and x.startswith('cite_note-'))
rows=[]
for link in links:
    # create a new dictionary with cite_id and hrefs
    # while creating cite id, replace 'note' with 'ref' for matching purposes
    new_dict = {'cite_id': link.get('id').replace('note','ref')}
    hrefs = link.find_all('a')
    link_list = []
    for ref in hrefs[1:]:
        link_list.append(ref['href'])
    new_dict['links'] = link_list
    rows.append(new_dict)

# %%
# convert it into a dataframe
import pandas as pd
linklist = pd.DataFrame(rows)
linklist
# Out:
#            cite_id                                              links
# 0       cite_ref-1  [http://www.cnn.com/2014/12/12/tech/twitter-se...
# 1       cite_ref-2  [https://www.google.ie/trends/2014/story/selfi...
# 2       cite_ref-3  [https://crashstats.nhtsa.dot.gov/Api/Public/V...
# 3       cite_ref-4  [https://www.washingtonpost.com/local/traffica...
# 4    cite_ref-:1-5  [#cite_ref-:1_5-1, https://www.washingtonpost....
# ..             ...                                                ...
# 217   cite_ref-218  [https://www.bbc.com/news/uk-england-lincolnsh...
# 218   cite_ref-219  [https://www.newschain.uk/news/woman-falls-her...
# 219   cite_ref-220  [https://www.theage.com.au/national/victoria/d...
# 220   cite_ref-221  [https://www.vecer.com/kronika/maribor-vlak-tr...
# 221   cite_ref-222  [https://www.thejakartapost.com/news/2021/05/1...
#
# [222 rows x 2 columns]

# %%
# we need to expand the first dataframe to merge it: explode()
sp_df= sp_df.explode('Source(s)')

# %%
# merge the corresponding links

sp_df= pd.merge(left=sp_df, right=linklist, left_on='Source(s)', right_on='cite_id')
sp_df.head(5)
# Out:
#         Date        Country  Injuries/Casualties           Type  \
# 0 2011-10-15  United States                    3      Transport
# 1 2011-10-15  United States                    3      Transport
# 2 2014-03-01          Spain                    1  Electrocution
# 3 2014-03-01         Russia                    1      Transport
# 4 2014-04-01  United States                    1      Transport
#
#                                          Description    Source(s)  \
# 0  Three teenagers (two sisters and a friend) wer...   cite_ref-8
# 1  Three teenagers (two sisters and a friend) wer...   cite_ref-9
# 2  A 21-year-old man was electrocuted after climb...  cite_ref-10
# 3  A train driver saw two people near the train t...  cite_ref-11
# 4  A 32-year-old woman from North Carolina was dr...  cite_ref-12
#
#        cite_id                                              links
# 0   cite_ref-8  [https://www.up.com/aboutup/community/inside_t...
# 1   cite_ref-9  [http://www.deseretnews.com/article/705392623/...
# 2  cite_ref-10  [http://www.thelocal.es/20140318/young-man-die...
# 3  cite_ref-11  [https://orsk.ru/news/86935#, https://web.arch...
# 4  cite_ref-12  [https://www.independent.co.uk/news/world/amer...

# %% [markdown]
# ## Export the dataset to a CSV file

# %%
# use pandas save it as a csv
sp_df.to_csv('scrapeddata.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## Exploratory Data Analysis
#
# This is the step to find interesting patterns or a storyline from the data.

# %%
# saving our final scraped dataset as df for common usage
df = sp_df

# %%
# To display the top 5 rows
df.head(5)
# Out:
#         Date        Country  Injuries/Casualties           Type  \
# 0 2011-10-15  United States                    3      Transport
# 1 2011-10-15  United States                    3      Transport
# 2 2014-03-01          Spain                    1  Electrocution
# 3 2014-03-01         Russia                    1      Transport
# 4 2014-04-01  United States                    1      Transport
#
#                                          Description    Source(s)  \
# 0  Three teenagers (two sisters and a friend) wer...   cite_ref-8
# 1  Three teenagers (two sisters and a friend) wer...   cite_ref-9
# 2  A 21-year-old man was electrocuted after climb...  cite_ref-10
# 3  A train driver saw two people near the train t...  cite_ref-11
# 4  A 32-year-old woman from North Carolina was dr...  cite_ref-12
#
#        cite_id                                              links
# 0   cite_ref-8  [https://www.up.com/aboutup/community/inside_t...
# 1   cite_ref-9  [http://www.deseretnews.com/article/705392623/...
# 2  cite_ref-10  [http://www.thelocal.es/20140318/young-man-die...
# 3  cite_ref-11  [https://orsk.ru/news/86935#, https://web.arch...
# 4  cite_ref-12  [https://www.independent.co.uk/news/world/amer...

# %%
# To display the bottom 5 rows
df.tail(5)
# Out:
#           Date    Country  Injuries/Casualties       Type  \
# 201 2020-01-12  Australia                    1       Fall
# 202 2020-04-30     Turkey                    1       Fall
# 203 2020-12-12  Australia                    1       Fall
# 204 2021-01-12   Slovenia                    1  Transport
# 205 2021-05-16  Indonesia                    9    Drowned
#
#                                            Description     Source(s)  \
# 201  A 21-year-old woman from Lincoln, England, fel...  cite_ref-218
# 202  A 31-year-old resident from Kazakhstan fell fr...  cite_ref-219
# 203  A 38-year-old woman from North Victoria fell 8...  cite_ref-220
# 204  A fatal accident in Maribor, Slovenia happened...  cite_ref-221
# 205  A boat overloaded with 20 people in a reservoi...  cite_ref-222
#
#           cite_id                                              links
# 201  cite_ref-218  [https://www.bbc.com/news/uk-england-lincolnsh...
# 202  cite_ref-219  [https://www.newschain.uk/news/woman-falls-her...
# 203  cite_ref-220  [https://www.theage.com.au/national/victoria/d...
# 204  cite_ref-221  [https://www.vecer.com/kronika/maribor-vlak-tr...
# 205  cite_ref-222  [https://www.thejakartapost.com/news/2021/05/1...

# %%
# Checking the data type
df.dtypes
# Out:
# Date                   datetime64[ns]
# Country                        object
# Injuries/Casualties             int32
# Type                           object
# Description                    object
# Source(s)                      object
# cite_id                        object
# links                          object
# dtype: object

# %%
# Dropping irrelevant columns: for now we will drop the source column
df = df.drop('Source(s)',axis=1)
df.head(5)
# Out:
#         Date        Country  Injuries/Casualties           Type  \
# 0 2011-10-15  United States                    3      Transport
# 1 2011-10-15  United States                    3      Transport
# 2 2014-03-01          Spain                    1  Electrocution
# 3 2014-03-01         Russia                    1      Transport
# 4 2014-04-01  United States                    1      Transport
#
#                                          Description      cite_id  \
# 0  Three teenagers (two sisters and a friend) wer...   cite_ref-8
# 1  Three teenagers (two sisters and a friend) wer...   cite_ref-9
# 2  A 21-year-old man was electrocuted after climb...  cite_ref-10
# 3  A train driver saw two people near the train t...  cite_ref-11
# 4  A 32-year-old woman from North Carolina was dr...  cite_ref-12
#
#                                                links
# 0  [https://www.up.com/aboutup/community/inside_t...
# 1  [http://www.deseretnews.com/article/705392623/...
# 2  [http://www.thelocal.es/20140318/young-man-die...
# 3  [https://orsk.ru/news/86935#, https://web.arch...
# 4  [https://www.independent.co.uk/news/world/amer...

# %%
# Rename columns for easier typing

df = df.rename(columns={'Injuries/Casualties': 'Persons'})

# %%
# Finding the null values: We have a complete dataset
print(df.isnull().sum())
# Out:
# Date           0
# Country        0
# Persons        0
# Type           0
# Description    0
# cite_id        0
# links          0
# dtype: int64

# %% [markdown]
# ## Coming up with questions

# %% [markdown]
# ##### Question
# - In which year were the most accidents?
# - Which year had the most casualties? 2014 really the year of selifes?
# - Is there a seasonal trend? Summer more deaths?
# - How did most people die?
# - Which were the biggest accidents?
# - Word analysis
# - Which country had the most selfie deaths?
#
# ##### Further explorations
#
# - Think about how to best visualize all that considering the sensitivity of deaths!
# - To Do: Scrape the location spots: Where are the selfie danger areas? Hotspot Attraction more dangerous? Mumbai created No Selfie Zones for example.
# - Scrape out the age and gender from the text
#
# From Wiki: A 2018 study of news reports showed that there were 259 selfie deaths in 137 incidents reported globally between October 2011 and November 2017, with the highest occurrences in India, followed by Russia, United States, and Pakistan. The mean age was 23 years old, with male deaths outnumbering female about three to one.
#
# - Request that dataset?

# %% [markdown]
# ### Which year had the most accidents? Which month has the most accidents?
#
# The United States Department of Transportation called 2014, the so-called "year of the selfie" as there were many accidents. Is that true?

# %%
# extracting the years and month from the Date column

import datetime
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

df
# Out:
#           Date        Country  Persons           Type  \
# 0   2011-10-15  United States        3      Transport
# 1   2011-10-15  United States        3      Transport
# 2   2014-03-01          Spain        1  Electrocution
# 3   2014-03-01         Russia        1      Transport
# 4   2014-04-01  United States        1      Transport
# ..         ...            ...      ...            ...
# 201 2020-01-12      Australia        1           Fall
# 202 2020-04-30         Turkey        1           Fall
# 203 2020-12-12      Australia        1           Fall
# 204 2021-01-12       Slovenia        1      Transport
# 205 2021-05-16      Indonesia        9        Drowned
#
#                                            Description       cite_id  \
# 0    Three teenagers (two sisters and a friend) wer...    cite_ref-8
# 1    Three teenagers (two sisters and a friend) wer...    cite_ref-9
# 2    A 21-year-old man was electrocuted after climb...   cite_ref-10
# 3    A train driver saw two people near the train t...   cite_ref-11
# 4    A 32-year-old woman from North Carolina was dr...   cite_ref-12
# ..                                                 ...           ...
# 201  A 21-year-old woman from Lincoln, England, fel...  cite_ref-218
# 202  A 31-year-old resident from Kazakhstan fell fr...  cite_ref-219
# 203  A 38-year-old woman from North Victoria fell 8...  cite_ref-220
# 204  A fatal accident in Maribor, Slovenia happened...  cite_ref-221
# 205  A boat overloaded with 20 people in a reservoi...  cite_ref-222
#
#                                                  links  Year  Month
# 0    [https://www.up.com/aboutup/community/inside_t...  2011     10
# 1    [http://www.deseretnews.com/article/705392623/...  2011     10
# 2    [http://www.thelocal.es/20140318/young-man-die...  2014      3
# 3    [https://orsk.ru/news/86935#, https://web.arch...  2014      3
# 4    [https://www.independent.co.uk/news/world/amer...  2014      4
# ..                                                 ...   ...    ...
# 201  [https://www.bbc.com/news/uk-england-lincolnsh...  2020      1
# 202  [https://www.newschain.uk/news/woman-falls-her...  2020      4
# 203  [https://www.theage.com.au/national/victoria/d...  2020     12
# 204  [https://www.vecer.com/kronika/maribor-vlak-tr...  2021      1
# 205  [https://www.thejakartapost.com/news/2021/05/1...  2021      5
#
# [206 rows x 9 columns]

# %%
# use sort_index() to sort the x-axis

df.Year.value_counts().sort_index().plot(kind='bar', title="Selfie Accidents by Year")
# Out:
# <AxesSubplot:title={'center':'Selfie Accidents by Year'}>

# %%
df.Month.value_counts().sort_index().plot(kind='bar', title="Selfie Accidents by Month")
# Out:
# <AxesSubplot:title={'center':'Selfie Accidents by Month'}>

# %% [markdown]
# There is a definite peak in the summer months for selfie deaths. Maybe because a lot of people go on vacation and travel to dangerous locations to take pictures. Or people take more pictures in general if the weather is better. What should be looked more into is why January has a peak.

# %% [markdown]
# ### Why are there so many accidents in January?

# %%
df[df.Month==1]
# Out:
#           Date       Country  Persons           Type  \
# 23  2015-01-01  South Africa        1           Fall
# 24  2015-01-01  South Africa        1           Fall
# 25  2015-01-01        Russia        2          Other
# 26  2015-01-01         India        3      Transport
# 61  2016-01-01         India        1      Transport
# 62  2016-01-01         India        1      Transport
# 63  2016-01-05   Philippines        1           Fall
# 64  2016-01-07        Brazil        1           Fall
# 65  2016-01-09         India        1           Fall
# 66  2016-01-09         India        2        Drowned
# 67  2016-01-09         India        2        Drowned
# 68  2016-01-09         India        2        Drowned
# 126 2017-01-01         India        1      Transport
# 127 2017-01-04      Pakistan        1        Drowned
# 128 2017-01-06       Croatia        2  Electrocution
# 129 2017-01-13         India        1        Drowned
# 130 2017-01-14         India        1      Transport
# 131 2017-01-14         India        2      Transport
# 132 2017-01-25         India        1      Transport
# 165 2018-01-08       Croatia        1  Electrocution
# 166 2018-01-11      Colombia        1           Fall
# 183 2019-01-04       Ireland        1           Fall
# 184 2019-01-04       Ireland        1           Fall
# 185 2019-01-10      Colombia        1           Fall
# 200 2020-01-08      Colombia        1           Fall
# 201 2020-01-12     Australia        1           Fall
# 204 2021-01-12      Slovenia        1      Transport
#
#                                            Description       cite_id  \
# 23   A 21-year-old woman died after falling from No...   cite_ref-31
# 24   A 21-year-old woman died after falling from No...   cite_ref-32
# 25   Two young men died in the Ural Mountains after...   cite_ref-33
# 26   Three students aged 20 to 22 died trying to ta...   cite_ref-34
# 61   A 16-year-old boy was killed by a passenger tr...   cite_ref-72
# 62   A 16-year-old boy was killed by a passenger tr...   cite_ref-73
# 63   A 19-year-old student fell to her death from t...   cite_ref-74
# 64   A 27-year-old man fell into the sea and died a...   cite_ref-75
# 65   A 20-year-old fell to his death while taking a...   cite_ref-76
# 66   A 20-year-old college student drowned at Bands...   cite_ref-77
# 67   A 20-year-old college student drowned at Bands...   cite_ref-78
# 68   A 20-year-old college student drowned at Bands...   cite_ref-79
# 126  A 21-year-old engineering student died when he...  cite_ref-143
# 127  In Sukkur, Pakistan, a man fell into the Indus...  cite_ref-144
# 128  In Rijeka, Croatia, two men climbed onto a con...  cite_ref-145
# 129  A woman, Ashana Bhandari, fell into the Alakna...  cite_ref-146
# 130  A second-year college student died while takin...  cite_ref-147
# 131  Two teenagers were crushed under a train while...  cite_ref-148
# 132  A 22-year-old man died while attempting to tak...  cite_ref-149
# 165  In Zagreb, Croatia, 14-year-old boy climbed on...  cite_ref-182
# 166  In Gámbita, Santander, Colombia, a 19-year-old...  cite_ref-183
# 183  A young Indian man died after falling off the ...  cite_ref-200
# 184  A young Indian man died after falling off the ...  cite_ref-201
# 185  A 32-year-old man died after fall down in a wa...  cite_ref-202
# 200  A 29-year-old woman died after falling 10m dow...  cite_ref-217
# 201  A 21-year-old woman from Lincoln, England, fel...  cite_ref-218
# 204  A fatal accident in Maribor, Slovenia happened...  cite_ref-221
#
#                                                  links  Year  Month
# 23   [http://www.news24.com/SouthAfrica/News/Joburg...  2015      1
# 24   [http://www.tnp.sg/news/world-news/tragic-love...  2015      1
# 25   [http://www.aljazeera.com/news/2015/07/russia-...  2015      1
# 26   [http://timesofindia.indiatimes.com/india/Self...  2015      1
# 61   [http://news.sky.com/story/1633671/teen-taking...  2016      1
# 62   [https://www.bbc.com/news/world-asia-india-354...  2016      1
# 63   [http://newsinfo.inquirer.net/752857/19-year-o...  2016      1
# 64   [http://g1.globo.com/sp/santos-regiao/noticia/...  2016      1
# 65   [http://indianexpress.com/article/india/india-...  2016      1
# 66   [http://timesofindia.indiatimes.com/city/mumba...  2016      1
# 67   [http://www.hindustantimes.com/mumbai/woman-dr...  2016      1
# 68   [http://www.indiatimes.com/news/india/mumbai-m...  2016      1
# 126  [http://www.hindustantimes.com/india-news/engg...  2017      1
# 127  [https://www.geo.tv/latest/126198-Deadly-selfi...  2017      1
# 128  [http://hr.n1info.com/a172512/Vijesti/Za-smrt-...  2017      1
# 129  [http://www.nyoooz.com/news/dehradun/724644/22...  2017      1
# 130  [https://www.youtube.com/watch?v=3XD_SmrjSwo, ...  2017      1
# 131  [http://timesofindia.indiatimes.com/city/delhi...  2017      1
# 132  [http://timesofindia.indiatimes.com/city/ludhi...  2017      1
# 165  [http://net.hr/danas/crna-kronika/horor-na-zap...  2018      1
# 166  [http://www.eltiempo.com/colombia/otras-ciudad...  2018      1
# 183  [https://www.breakingnews.ie/ireland/student-d...  2019      1
# 184  [https://www.buzz.ie/news/young-man-dies-takin...  2019      1
# 185  [https://www.noticias.caracoltv.com/valle/una-...  2019      1
# 200  [https://www.eltiempo.com/amp/colombia/otras-c...  2020      1
# 201  [https://www.bbc.com/news/uk-england-lincolnsh...  2020      1
# 204  [https://www.vecer.com/kronika/maribor-vlak-tr...  2021      1

# %% [markdown]
# There is no real reason for the peak in January and has not much to do with the month.

# %% [markdown]
# ### Which year had the most casualties?

# %%
df.groupby(by='Year').Persons.sum().plot(kind='bar', title="Selfie Casualty Count by Year")
# Out:
# <AxesSubplot:title={'center':'Selfie Casualty Count by Year'}, xlabel='Year'>

# %% [markdown]
# **Here it is really interesting to see while 2016 had the most accidents, 2017 was the deadliest year so far.**

# %% [markdown]
# ## Downloading the csv for the first visualization

# %%
# create a dataframe

cas=df.groupby(by='Year').Persons.sum().sort_index().reset_index()
cas.rename(columns = {'Persons':'Casualty/Injury Count'}, inplace = True)
cas
# Out:
#    Year  Casualty/Injury Count
# 0  2011                      6
# 1  2014                     23
# 2  2015                     58
# 3  2016                    111
# 4  2017                    112
# 5  2018                     28
# 6  2019                     27
# 7  2020                      4
# 8  2021                     10

# %%
#create a dataframe

acc=df.Year.value_counts().sort_index().reset_index()
acc.rename(columns = {'index':'Year', 'Year':'Accident Count'}, inplace = True)
acc
# Out:
#    Year  Accident Count
# 0  2011               2
# 1  2014              21
# 2  2015              38
# 3  2016              65
# 4  2017              39
# 5  2018              18
# 6  2019              17
# 7  2020               4
# 8  2021               2

# %%
# merge the 2 dataframes on year

df_cd = pd.merge(cas, acc, how='inner', on = 'Year')
df_cd
# Out:
#    Year  Casualty/Injury Count  Accident Count
# 0  2011                      6               2
# 1  2014                     23              21
# 2  2015                     58              38
# 3  2016                    111              65
# 4  2017                    112              39
# 5  2018                     28              18
# 6  2019                     27              17
# 7  2020                      4               4
# 8  2021                     10               2

# %%
# use pandas save it as a csv
df_cd.to_csv('viz-1.csv', index=False, encoding='utf-8')

# %% [markdown]
# ### Most common accident types

# %%
df.Type.value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# This aligns with the findings from [TechnologyReview](https://www.technologyreview.com/2016/11/15/156018/data-scientists-chart-the-tragic-rise-of-selfie-deaths/)
#
# *The team also found that the most common cause of death was falling from a height. This reflects the penchant for people taking selfies at the edge of cliffs, at the top of tall structures, and so on.Water also accounts for a large number of deaths. And a significant number involve water and heights—things like jumping into the sea from a height and so on.*

# %%
# save as csv
df.Type.value_counts().reset_index().to_csv('viz-2.csv', index=False, encoding='utf-8')

# %%
# plot the accident types by year

df.groupby(by='Year').Type.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Year,Type'>

# %%
df[(df.Year==2016) & (df.Type=='Fall')]
# Out:
#           Date           Country  Persons  Type  \
# 63  2016-01-05       Philippines        1  Fall
# 64  2016-01-07            Brazil        1  Fall
# 65  2016-01-09             India        1  Fall
# 72  2016-02-22             India        5  Fall
# 76  2016-03-12  Hong Kong, China        1  Fall
# 77  2016-04-05             India        1  Fall
# 78  2016-04-05             India        1  Fall
# 80  2016-04-16            Brazil        1  Fall
# 82  2016-04-21            Brazil        1  Fall
# 85  2016-06-18     United States        1  Fall
# 86  2016-06-18     United States        1  Fall
# 88  2016-06-22             India        1  Fall
# 89  2016-06-22             India        1  Fall
# 90  2016-06-29              Peru        1  Fall
# 91  2016-07-02             India        1  Fall
# 93  2016-07-12             India        1  Fall
# 98  2016-07-19             India        2  Fall
# 99  2016-07-23             India        1  Fall
# 103 2016-07-31             India        2  Fall
# 105 2016-08-03             India        1  Fall
# 106 2016-08-07             India        1  Fall
# 108 2016-08-12             India        1  Fall
# 110 2016-08-15             India        1  Fall
# 119 2016-10-09             India        1  Fall
# 123 2016-10-18            Russia        1  Fall
#
#                                            Description       cite_id  \
# 63   A 19-year-old student fell to her death from t...   cite_ref-74
# 64   A 27-year-old man fell into the sea and died a...   cite_ref-75
# 65   A 20-year-old fell to his death while taking a...   cite_ref-76
# 72   Five people in Anjuna, Goa, fell off a cliff a...   cite_ref-83
# 76   A 30-year-old man fell off Lion Rock in Hong K...   cite_ref-87
# 77   A 16-year-old climbed a rock fountain at a zoo...   cite_ref-88
# 78   A 16-year-old climbed a rock fountain at a zoo...   cite_ref-89
# 80   A 27-year-old woman fell from a height of 35m ...   cite_ref-91
# 82   In Campos dos Goytacazes in Rio de Janeiro, a ...   cite_ref-93
# 85   A 37-year-old EMS lieutenant of the New York C...  cite_ref-100
# 86   A 37-year-old EMS lieutenant of the New York C...  cite_ref-101
# 88   A third year engineering student of a Lonavla-...  cite_ref-103
# 89   A third year engineering student of a Lonavla-...  cite_ref-104
# 90   A 51-year-old German tourist visiting Machu Pi...  cite_ref-106
# 91   A 32-year-old resident of Mali Mohalla, near S...  cite_ref-107
# 93   A 36-year-old and a friend climbed to a mounta...  cite_ref-109
# Nepal                2
# Turkey               2
# Uganda               1
# Greece               1
# Peru                 1
# Slovenia             1
# Serbia               1
# Chile                1
# Hungary              1
# Hong Kong, China     1
# Malaysia             1
# Oman                 1
# Kenya                1
# Romania              1
# Panama               1
# Vietnam              1
# Nigeria              1
# Name: Country, dtype: int64

# %% [markdown]
# Like this [Washington Post](https://www.washingtonpost.com/news/worldviews/wp/2016/01/14/more-people-die-taking-selfies-in-india-than-anywhere-else-in-the-world/) reported in January 2016, India still remains the country with the most accidents nearly quadruple the count of the second country, which is the US.

# %%
# save the Top 10 countries as csv

df.Country.value_counts().head(10).reset_index().to_csv('viz-2-2.csv', index=False, encoding='utf-8')

# %% [markdown]
# ### How do India's numbers look nowadays

# %%
df[df.Year>=2017].Country.value_counts()
# Out:
# India             23
# United States      8
# Australia          5
# Pakistan           3
# Germany            3
# Colombia           3
# Mexico             3
# Sri Lanka          3
# United Kingdom     3
# Indonesia          2
# Brazil             2
# Croatia            2
# Ireland            2
# Russia             2
# Italy              2
# Thailand           2
# New Zealand        2
# Greece             1
# Slovenia           1
# Uganda             1
# Spain              1
# Panama             1
# Malaysia           1
# Hungary            1
# Portugal           1
# Nigeria            1
# Turkey             1
# Name: Country, dtype: int64

# %%
df[df.Year>2018].Country.value_counts()
# Out:
# Australia        3
# India            3
# Pakistan         2
# Ireland          2
# Colombia         2
# Germany          2
# Italy            2
# Indonesia        1
# Turkey           1
# United States    1
# Uganda           1
# Spain            1
# Slovenia         1
# Thailand         1
# Name: Country, dtype: int64

# %% [markdown]
# ### A little Text Analysis (work in progress)

# %%
# Concatonating all the text in the description column and give me the first 1000 characters

all_text = df.Description.str.cat(sep=" ")
all_text[:1000]
# Out:
# 'Three teenagers (two sisters and a friend) were killed by a train while posing for a selfie that was found on their phone. Shortly before, they posted the message "Standing right by a train ahaha this is awesome!!!!" to Facebook. Three teenagers (two sisters and a friend) were killed by a train while posing for a selfie that was found on their phone. Shortly before, they posted the message "Standing right by a train ahaha this is awesome!!!!" to Facebook. A 21-year-old man was electrocuted after climbing on top of a train to take a selfie with friends and touching a wire that (contrary to the assumptions of the group) turned out to be live. One of the friends was hospitalized in serious condition. A train driver saw two people near the train tracks in front of them and applied the emergency brake and sounded the horn. One of the people on the tracks moved away and the second, a 15-year-old, was attempting to take a selfie when a collision occurred with the train and they were killed. A'

# %%
# clean the text

cleaned_text= all_text.replace("."," ").replace(","," ").replace("\n"," ").replace("("," ").replace(")"," ").replace("  "," ").lower()

cleaned_text[:1000]
# Out:
# 'three teenagers two sisters and a friend were killed by a train while posing for a selfie that was found on their phone shortly before they posted the message "standing right by a train ahaha this is awesome!!!!" to facebook three teenagers two sisters and a friend were killed by a train while posing for a selfie that was found on their phone shortly before they posted the message "standing right by a train ahaha this is awesome!!!!" to facebook a 21-year-old man was electrocuted after climbing on top of a train to take a selfie with friends and touching a wire that contrary to the assumptions of the group turned out to be live one of the friends was hospitalized in serious condition a train driver saw two people near the train tracks in front of them and applied the emergency brake and sounded the horn one of the people on the tracks moved away and the second a 15-year-old was attempting to take a selfie when a collision occurred with the train and they were killed a 32-year-old woman'

# %%
# creating a list with all the words

words=cleaned_text.split(" ")
words
# Out:
# ['three',
#  'teenagers',
#  'two',
#  'sisters',
#  'and',
#  'a',
#  'friend',
#  'were',
#  'killed',
#  'by',
#  'a',
#  'train',
#  'while',
#  'posing',
#  'for',
#  'a',
#  'selfie',
#  'that',
#  'was',
#  'found',
#  'on',
#  'their',
#  'phone',
#  'shortly',
#  'before',
#  'they',
#  'posted',
#  'the',
#  'message',
#  '"standing',
#  'right',
#  'by',
#  'a',
#  'train',
#  'ahaha',
#  'this',
#  'is',
#  'awesome!!!!"',
#  'to',
#  'facebook',
#  'three',
#  'teenagers',
#  'two',
#  'sisters',
#  'and',
#  'a',
#  'friend',
#  'were',
#  'killed',
#  'by',
#  'a',
#  'train',
#  'while',
#  'posing',
#  'for',
#  'a',
#  'selfie',
#  'that',
#  'was',
#  'found',
#  'on',
#  'their',
#  'phone',
#  'shortly',
#  'before',
#  'they',
#  'posted',
#  'the',
#  'message',
#  '"standing',
#  'right',
#  'by',
#  'a',
#  'train',
#  'ahaha',
#  'this',
#  'is',
#  'awesome!!!!"',
#  'to',
#  'facebook',
#  'a',
#  '21-year-old',
#  'man',
#  'was',
#  'electrocuted',
#  'after',
#  'climbing',
#  'on',
#  'top',
#  'of',
#  'a',
#  'train',
#  'to',
#  'take',
#  'a',
#  'selfie',
#  'with',
#  'friends',
#  'and',
#  'touching',
#  'a',
#  'wire',
#  'that',
#  'contrary',
#  'to',
#  'the',
#  'assumptions',
#  'of',
#  'the',
#  'group',
#  'turned',
#  'out',
#  'to',
#  'be',
#  'live',
#  'one',
#  'of',
#  'the',
#  'friends',
#  'was',
#  'hospitalized',
#  'in',
#  'serious',
#  'condition',
#  'a',
#  'train',
#  'driver',
#  'saw',
#  'two',
#  'people',
#  'near',
#  'the',
#  'train',
#  'tracks',
#  'in',
#  'front',
#  'of',
#  'them',
#  'and',
#  'applied',
#  'the',
#  'emergency',
#  'brake',
#  'and',
#  'sounded',
#  'the',
#  'horn',
#  'one',
#  'of',
#  'the',
#  'people',
#  'on',
#  'the',
#  'tracks',
#  'moved',
#  'away',
#  'and',
#  'the',
#  'second',
#  'a',
#  '15-year-old',
#  'was',
#  'attempting',
#  'to',
#  'take',
#  'a',
#  'selfie',
#  'when',
#  'a',
#  'collision',
#  'occurred',
#  'with',
#  'the',
#  'train',
#  'and',
#  'they',
#  'were',
#  'killed',
#  'a',
#  '32-year-old',
#  'woman',
#  'from',
#  'north',
#  'carolina',
#  'was',
#  'driving',
#  'when',
#  'her',
#  'vehicle',
#  'veered',
#  'across',
#  'the',
#  'center',
#  'median',
#  'collided',
#  'with',
#  'a',
#  'recycling',
#  'truck',
#  'left',
#  'the',
#  'road',
#  'hit',
#  'a',
#  'tree',
#  'and',
#  'burst',
#  'into',
#  'flames',
#  '–',
#  'moments',
#  'after',
#  'posting',
#  'selfies',
#  'online',
#  'when',
#  'she',
#  'heard',
#  'pharrell',
#  "williams'",
#  'song',
#  '"happy"',
#  'the',
#  'truck',
#  'driver',
#  'was',
#  'unharmed',
#  'a',
#  '32-year-old',
#  'woman',
#  'from',
#  'north',
#  'carolina',
#  'was',
#  'driving',
#  'when',
#  'her',
#  'vehicle',
#  'veered',
#  'across',
#  'the',
#  'center',
#  'median',
#  'collided',
#  'with',
#  'a',
#  'recycling',
#  'truck',
#  'left',
#  'the',
#  'road',
#  'hit',
#  'a',
#  'tree',
#  'and',
#  'burst',
#  'into',
#  'flames',
#  '–',
#  'moments',
#  'after',
#  'posting',
#  'selfies',
#  'online',
#  'when',
#  'she',
#  'heard',
#  'pharrell',
#  "williams'",
#  'song',
#  '"happy"',
#  'the',
#  'truck',
#  'driver',
#  'was',
#  'unharmed',
#  'a',
#  '17-year-old',
#  'girl',
#  'fell',
#  '30\xa0ft',
#  'to',
#  'her',
#  'death',
#  'after',
#  'being',
#  'hit',
#  'by',
#  '1',
#  '500',
#  'volts',
#  'when',
#  'attempting',
#  'to',
#  'grab',
#  'live',
#  'wires',
#  'on',
#  'a',
#  'railway',
#  'bridge',
#  'a',
#  '15-year-old',
#  'boy',
#  'was',
#  'killed',
#  'by',
#  'a',
#  'train',
#  'while',
#  'posing',
#  'for',
#  'a',
#  'selfie',
#  'on',
#  'the',
#  'tracks',
#  'a',
#  '29-year-old',
#  'amateur',
#  'pilot',
#  'allegedly',
#  'took',
#  'selfies',
#  'using',
#  'a',
#  'gopro',
#  'camera',
#  'before',
#  'his',
#  'plane',
#  'crashed',
#  'killing',
#  'himself',
#  'and',
#  'the',
#  'passenger',
#  'on',
#  'board',
#  'a',
#  '16-year-old',
#  'girl',
#  'died',
#  'in',
#  'taranto',
#  'after',
#  'plunging',
#  '60',
#  'feet',
#  'onto',
#  'rocks',
#  'while',
#  'she',
#  'was',
#  'trying',
#  'to',
#  'take',
#  'a',
#  'photograph',
#  'of',
#  'herself',
#  'on',
#  'the',
#  'seafront',
#  'a',
#  '14-year-old',
#  'high',
#  'school',
#  'student',
#  'in',
#  'the',
#  'philippines',
#  'fell',
#  'to',
#  'her',
#  'death',
#  'after',
#  'losing',
#  'her',
#  'balance',
#  'while',
#  'taking',
#  'a',
#  'selfie',
#  'with',
#  'a',
#  'friend',
#  'near',
#  'a',
#  'staircase',
#  'landing',
#  'of',
#  'their',
#  'school',
#  'in',
#  'suburban',
#  'pasig',
#  '',
#  'according',
#  'to',
#  'doctors',
#  'she',
#  'sustained',
#  'a',
#  'sharp',
#  'blow',
#  'to',
#  'the',
#  'head',
#  'from',
#  'the',
#  'fall',
#  'and',
#  'broke',
#  'a',
#  'rib',
#  'which',
#  'pierced',
#  'a',
#  'kidney',
#  'a',
#  '12',
#  'year-old',
#  'was',
#  'with',
#  'a',
#  'second',
#  'person',
#  'taking',
#  'selfies',
#  'near',
#  'a',
#  'railway',
#  'track',
#  'a',
#  'train',
#  'arrived',
#  'and',
#  'they',
#  'went',
#  'back',
#  'down',
#  'onto',
#  'the',
#  'train',
#  'tracks',
#  'to',
#  'retrieve',
#  'their',
#  'bags',
#  'as',
#  'they',
#  'were',
#  'waiting',
#  'for',
#  'the',
#  'train',
#  'to',
#  'leave',
#  'a',
#  'second',
#  'train',
#  'approached',
#  'that',
#  'they',
#  'did',
#  'not',
#  'hear',
#  'the',
#  'second',
#  'person',
#  'jumped',
#  'away',
#  'before',
#  'the',
#  'train',
#  'collided',
#  'with',
#  'them',
#  'and',
#  'the',
#  '12',
#  'year-old',
#  'was',
#  'hit',
#  'by',
#  'the',
#  'train',
#  'and',
#  'killed',
#  'a',
#  '12',
#  'year-old',
#  'was',
#  'with',
#  'a',
#  'second',
#  'person',
#  'taking',
#  'selfies',
#  'near',
#  'a',
#  'railway',
#  'track',
#  'a',
#  'train',
#  'arrived',
#  'and',
#  'they',
#  'went',
#  'back',
#  'down',
#  'onto',
#  'the',
#  'train',
#  'tracks',
#  'to',
#  'retrieve',
#  'their',
#  'bags',
#  'as',
#  'they',
#  'were',
#  'waiting',
#  'for',
#  'the',
#  'train',
#  'to',
#  'leave',
#  'a',
#  'second',
#  'train',
#  'approached',
#  'that',
#  'they',
#  'did',
#  'not',
#  'hear',
#  'the',
#  'second',
#  'person',
#  'jumped',
#  'away',
#  'before',
#  'the',
#  'train',
#  'collided',
#  'with',
#  'them',
#  'and',
#  'the',
#  '12',
#  'year-old',
#  'was',
#  'hit',
#  'by',
#  'the',
#  'train',
#  'and',
#  'killed',
#  'a',
#  '15-year-old',
#  'boy',
#  'in',
#  'the',
#  'philippines',
#  'was',
#  'critically',
#  'wounded',
#  'after',
#  'accidentally',
#  'shooting',
#  'himself',
#  'while',
#  'taking',
#  'a',
#  'selfie',
#  'in',
#  'which',
#  'his',
#  'other',
#  'hand',
#  'was',
#  'holding',
#  'a',
#  'gun',
#  'to',
#  'his',
#  'chin',
#  'a',
#  '21-year-old',
#  'man',
#  'was',
#  'drinking',
#  'with',
#  'friends',
#  'and',
#  'took',
#  'a',
#  'selfie',
#  'to',
#  'post',
#  'on',
#  'facebook',
#  'he',
#  'posed',
#  'with',
#  'a',
#  'gun',
#  'pointed',
#  'at',
#  'his',
#  'face',
#  'the',
#  'man',
#  'accidentally',
#  'shot',
#  'himself',
#  'and',
#  'he',
#  'was',
#  'declared',
#  'dead',
#  'at',
#  'the',
#  'scene',
#  'a',
#  'polish',
#  'couple',
#  'fell',
#  'to',
#  'their',
#  'death',
#  'off',
#  'a',
#  'cliff',
#  'in',
#  'portugal',
#  'after',
#  'crossing',
#  'a',
#  'safety',
#  'barrier',
#  'to',
#  'take',
#  'a',
#  'selfie',
#  'with',
#  'their',
#  'children',
#  'their',
#  'two',
#  'children',
#  'who',
#  'were',
#  'present',
#  'at',
#  'the',
#  'scene',
#  'survived',
#  'in',
#  'kerala',
#  'a',
#  '14-year-old',
#  'boy',
#  'was',
#  'electrocuted',
#  'while',
#  'attempting',
#  'to',
#  'take',
#  'a',
#  'selfie',
#  'on',
#  'top',
#  'of',
#  'a',
#  'stationary',
#  'train',
#  'a',
#  '36-year-old',
#  'man',
#  'of',
#  'niagara',
#  'n',
#  'd',
#  '',
#  'struck',
#  'and',
#  'killed',
#  'a',
#  '54-year-old',
#  'woman',
#  'of',
#  'portland',
#  'n',
#  'd',
#  '',
#  'while',
#  'driving',
#  'she',
#  'was',
#  'riding',
#  'a',
#  'bicycle',
#  'and',
#  'he',
#  'was',
#  'distracted',
#  'as',
#  'he',
#  'took',
#  'a',
#  'selfie',
#  'striking',
#  'her',
#  'from',
#  'behind',
#  'with',
#  'his',
#  'vehicle',
#  'an',
#  '18-year-old',
#  'woman',
#  'in',
#  'the',
#  'philippines',
#  'was',
#  'posing',
#  'for',
#  'a',
#  'group',
#  'selfie',
#  'on',
#  'a',
#  'beach',
#  'with',
#  'friends',
#  'she',
#  'was',
#  'captured',
#  'by',
#  'a',
#  'strong',
#  'wave',
#  'and',
#  'drowned',
#  'an',
#  '18-year-old',
#  'woman',
#  'in',
#  'the',
#  'philippines',
#  'was',
#  'posing',
#  'for',
#  'a',
#  'group',
#  'selfie',
#  'on',
#  'a',
#  'beach',
#  'with',
#  'friends',
#  'she',
#  'was',
#  'captured',
#  'by',
#  'a',
#  'strong',
#  'wave',
#  'and',
#  'drowned',
#  'an',
#  '18-year-old',
#  'woman',
#  'in',
#  'the',
#  'philippines',
#  'was',
#  'posing',
#  'for',
#  'a',
#  'group',
#  'selfie',
#  'on',
#  'a',
#  'beach',
#  'with',
#  'friends',
#  'she',
#  'was',
#  'captured',
#  'by',
#  'a',
#  'strong',
#  'wave',
#  'and',
#  'drowned',
#  'a',
#  '23-year-old',
#  'student',
#  'from',
#  'poland',
#  'fell',
#  'to',
#  'her',
#  'death',
#  'while',
#  'trying',
#  'to',
#  'take',
#  'a',
#  'selfie',
#  'on',
#  'the',
#  'ledge',
#  'of',
#  'the',
#  'triana',
#  'bridge',
#  'in',
#  'seville',
#  'spain',
#  'a',
#  '23-year-old',
#  'student',
#  'from',
#  'poland',
#  'fell',
#  'to',
#  'her',
#  'death',
#  'while',
#  'trying',
#  'to',
#  'take',
#  'a',
#  'selfie',
#  'on',
#  'the',
#  'ledge',
#  'of',
#  'the',
#  'triana',
#  'bridge',
#  'in',
#  'seville',
#  'spain',
#  'a',
#  '21-year-old',
#  'woman',
#  'died',
#  'after',
#  'falling',
#  'from',
#  'northcliff',
#  'hill',
#  'johannesburg',
#  'as',
#  'a',
#  'male',
#  'companion',
#  'was',
#  'setting',
#  'up',
#  'a',
#  'tripod',
#  'for',
#  'a',
#  'selfie',
#  'reports',
#  'vary',
#  'as',
#  'to',
#  'the',
#  'identity',
#  'of',
#  'the',
#  'companion',
#  'a',
#  '21-year-old',
#  'woman',
#  'died',
#  'after',
#  'falling',
#  'from',
#  'northcliff',
#  'hill',
#  'johannesburg',
#  'as',
#  'a',
#  'male',
#  'companion',
#  'was',
#  'setting',
#  'up',
#  'a',
#  'tripod',
#  'for',
#  'a',
#  'selfie',
#  'reports',
#  'vary',
#  'as',
#  'to',
#  'the',
#  'identity',
#  'of',
#  'the',
#  'companion',
#  'two',
#  'young',
#  'men',
#  'died',
#  'in',
#  'the',
#  'ural',
#  'mountains',
#  'after',
#  'they',
#  'pulled',
#  'the',
#  'pin',
#  'from',
#  'a',
#  'live',
#  'hand',
#  'grenade',
#  'to',
#  'take',
#  'a',
#  'selfie',
#  'the',
#  'phone',
#  'with',
#  'the',
#  'picture',
#  'remained',
#  'as',
#  'evidence',
#  'of',
#  'the',
#  'circumstance',
#  'of',
#  'their',
#  'deaths',
#  'three',
#  'students',
#  'aged',
#  '20',
#  'to',
#  '22',
#  'died',
#  'trying',
#  'to',
#  'take',
#  'a',
#  '"daredevil',
#  'selfie"',
#  'close',
#  'to',
#  'an',
#  'oncoming',
#  'train',
#  'on',
#  'railway',
#  'tracks',
#  'of',
#  'mathura',
#  'near',
#  'kosikala',
#  'an',
#  'israeli',
#  'man',
#  'traveling',
#  'on',
#  'a',
#  'train',
#  'from',
#  'mumbai',
#  'to',
#  'goa',
#  'in',
#  'india',
#  'was',
#  'attempting',
#  'to',
#  'take',
#  'a',
#  'selfie',
#  'and',
#  'fell',
#  'out',
#  'of',
#  'the',
#  'moving',
#  'train',
#  'resulting',
#  'in',
#  ...]

# %%
# import a new library

from collections import Counter #Counter needs to be capital C!!!

# %%
# count all the words an appearances

counts= Counter(words)

# %%
pd.DataFrame(counts.most_common(30), columns=("words","count"))
# Out:
#       words  count
# 0         a    589
# 1       the    418
# 2        to    252
# 3        in    231
# 4        of    172
# 5       and    169
# 6       was    160
# 7    selfie    142
# 8     while    112
# 9        on    108
# 10     from     99
# 11   taking     99
# 12     take     82
# 13     with     78
# 14       at     78
# 15     were     72
# 16     fell     72
# 17    train     71
# 18     died     65
# 19      she     61
# 20       by     57
# 21      her     56
# 22     they     55
# 23      his     54
# 24       he     54
# 25    india     53
# 26    after     52
# 27  selfies     51
# 28     when     50
# 29      man     47

# %% [markdown]
# The word train appears quite often as well as India.

# %%
df[df.Description.str.contains('train')]
# Out:
#           Date        Country  Persons           Type  \
# 0   2011-10-15  United States        3      Transport
# 1   2011-10-15  United States        3      Transport
# 2   2014-03-01          Spain        1  Electrocution
# 3   2014-03-01         Russia        1      Transport
# 7   2014-05-01          India        1      Transport
# 11  2014-07-24        Belgium        1      Transport
# 12  2014-07-24        Belgium        1      Transport
# 16  2014-08-01          India        1  Electrocution
# 26  2015-01-01          India        3      Transport
# 27  2015-02-04          India        1      Transport
# 28  2015-02-21  United States        1      Transport
# 32  2015-04-01         Serbia        1      Transport
# 33  2015-05-01        Romania        2  Electrocution
# 39  2015-06-01         Russia        2  Electrocution
# 47  2015-08-01         Russia        1  Electrocution
# 54  2015-10-01          Spain        1  Electrocution
# 57  2015-11-01          India        2      Transport
# 58  2015-11-01          India        1  Electrocution
# 59  2015-12-01       Pakistan        1      Transport
# 61  2016-01-01          India        1      Transport
# 62  2016-01-01          India        1      Transport
# 79  2016-04-15          India        2      Transport
# 96  2016-07-13        Vietnam        2      Transport
# 120 2016-10-09      Sri Lanka        1      Transport
# 126 2017-01-01          India        1      Transport
# 128 2017-01-06        Croatia        2  Electrocution
# 130 2017-01-14          India        1      Transport
# 131 2017-01-14          India        2      Transport
# 132 2017-01-25          India        1      Transport
# 140 2017-04-13          India        5      Transport
# 144 2017-05-30          India        2      Transport
# 146 2017-06-11      Sri Lanka        2      Transport
# 147 2017-06-11         Russia        4      Transport
# 148 2017-06-11         Russia        4      Transport
# 149 2017-06-13      Sri Lanka        2      Transport
# 158 2017-08-11          India        1  Electrocution
# 159 2017-08-26          India        1  Electrocution
# 165 2018-01-08        Croatia        1  Electrocution
# 167 2018-02-09       Thailand        2      Transport
# 204 2021-01-12       Slovenia        1      Transport
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      
# 147                                                                                                                                                                                                                                                                                                                                                        Four children aged 10 to 13 were hit by a train while trying to take a selfie on a railway line in Nadezhdinsky District of Primorsky Krai, 43 km northwest of Vladivostok, Russia. Three were killed and one survived with injuries.
# 148                                                                                                                                                                                                                                                                                                                                                        Four children aged 10 to 13 were hit by a train while trying to take a selfie on a railway line in Nadezhdinsky District of Primorsky Krai, 43 km northwest of Vladivostok, Russia. Three were killed and one survived with injuries.
# 149                                                                                                                                                                                                                                                                     A 24-year-old groom was killed and his bride seriously injured when the newly-wed couple tried to take a selfie on the railway track at Kahawa, in the Southern Province, Sri Lanka. According to eyewitnesses, the couple had ignored warning signals given by the people in the area saying that the train was coming.
# 158                                                                                                                                                                                                                                                                                                                                                                                                       A 17-year-old boy climbed on top of a train in Ambarnath, India, to take a selfie but came into contact with a live wire, suffering severe injuries from the resulting electric shock.
# 159                                                                                                                                                                                                                                                                                                                                                                                      A 17-year-old boy attempted to take a selfie on top of a train carriage in Tambaram railway station, India. He touched a live wire, suffered severe burns from electric shock and died four days later.
# 165                                                                                                                                                                                                                                                                                                                                   In Zagreb, Croatia, 14-year-old boy climbed onto the roof of a train cargo wagon where he wanted to take a selfie. He was electrocuted and his body "burned like a torch." Firefighters were unable to take action until the train's power was turned off.
# 167                                                                                                                                                                                                                                        A 24-year-old Thai woman died as a result of her injuries when a train hit her while attempting to take a photo with an outgoing train in the background near Samsen train station in Bangkok's Phaya Thai District. A man, believed to be a colleague of the victim, was knocked unconscious by the train, suffering a head injury and a broken arm.
# 204                                                                                                                                                A fatal accident in Maribor, Slovenia happened when two minors were taking selfies in front of an oncoming train between two tracks. One of them was killed and the other managed to bounce, but ended up in hospital due to the shock. The unfortunate 14-year-old minor who died and her friend were photographed between the tracks next to the railway platform in front of a train coming from the direction of Ljubljana at high speed.
#
#           cite_id  \
# 0      cite_ref-8
# 1      cite_ref-9
# 2     cite_ref-10
# 3     cite_ref-11
# 7     cite_ref-15
# 11    cite_ref-19
# 12    cite_ref-20
# 16    cite_ref-24
# 26    cite_ref-34
# 27    cite_ref-35
# 28    cite_ref-36
# 32    cite_ref-40
# 33    cite_ref-41
# 39    cite_ref-47
# 47    cite_ref-57
# 54    cite_ref-64
# 57    cite_ref-67
# 58    cite_ref-68
# 59    cite_ref-70
# 61    cite_ref-72
# 62    cite_ref-73
# 79    cite_ref-90
# 96   cite_ref-112
# 120  cite_ref-137
# 126  cite_ref-143
# 128  cite_ref-145
# 130  cite_ref-147
# 131  cite_ref-148
# 132  cite_ref-149
# 140  cite_ref-157
# 144  cite_ref-161
# 146  cite_ref-163
# 147  cite_ref-164
# 148  cite_ref-165
# 149  cite_ref-166
# 158  cite_ref-175
# 159  cite_ref-176
# 165  cite_ref-182
# 167  cite_ref-184
# 204  cite_ref-221
#
#                                                                                                                                                                                                                                                                                                                                                                        links  \
# 165  [http://net.hr/danas/crna-kronika/horor-na-zapadnom-kolodvoru-u-zagrebu-djecak-se-popeo-na-krov-vagona-zbog-selfieja-udarila-ga-struja-nakon-cega-se-zapalio/, https://web.archive.org/web/20180109095122/http://net.hr/danas/crna-kronika/horor-na-zapadnom-kolodvoru-u-zagrebu-djecak-se-popeo-na-krov-vagona-zbog-selfieja-udarila-ga-struja-nakon-cega-se-zapalio/]
# 167                                                                     [https://www.telegraph.co.uk/news/2018/02/09/woman-killed-posing-selfie-train-tracks-thailand/, /wiki/ISSN_(identifier), //www.worldcat.org/issn/0307-1235, https://web.archive.org/web/20180209134513/http://www.telegraph.co.uk/news/2018/02/09/woman-killed-posing-selfie-train-tracks-thailand/]
# 204                                                                                                                                                                                                                                                  [https://www.vecer.com/kronika/maribor-vlak-trcil-v-mladoletnico-je-bila-tragedija-posledica-nevarnega-izziva-10232433]
#
#      Year  Month
# 0    2011     10
# 1    2011     10
# 2    2014      3
# 3    2014      3
# 7    2014      5
# 11   2014      7
# 12   2014      7
# 16   2014      8
# 26   2015      1
# 27   2015      2
# 28   2015      2
# 32   2015      4
# 33   2015      5
# 39   2015      6
# 47   2015      8
# 54   2015     10
# 57   2015     11
# 58   2015     11
# 59   2015     12
# 61   2016      1
# 62   2016      1
# 79   2016      4
# 96   2016      7
# 120  2016     10
# 126  2017      1
# 128  2017      1
# 130  2017      1
# 131  2017      1
# 132  2017      1
# 140  2017      4
# 144  2017      5
# 146  2017      6
# 147  2017      6
# 148  2017      6
# 149  2017      6
# 158  2017      8
# 159  2017      8
# 165  2018      1
# 167  2018      2
# 204  2021      1

# %%
# returns all numbers
import re

age = re.findall("[\d].", cleaned_text)

pd.DataFrame(Counter(age).most_common(30), columns=("Possible Age","Count"))
# Out:
#    Possible Age  Count
# 0            20     22
# 1            21     17
# 2            22     13
# 3            18     12
# 4            17     11
# 5            16     11
# 6            15     10
# 7            0      10
# 8            14     10
# 9            19      9
# 10           12      8
# 11           60      7
# 12           25      7
# 13           27      6
# 14           0-      6
# 15           32      5
# 16           30      5
# 17           50      5
# 18           00      5
# 19           24      5
# 20           10      5
# 21           13      4
# 22           36      3
# 23           23      3
# 24           43      3
# 25           35      3
# 26           40      3
# 27           1       2
# 28           29      2
# 29           80      2

# %% [markdown]
# Most people involved were in their early 20s, but a more detailed analysis is necessary to assign the age and maybe gender to the cases.

# %%
gender_dict = {"male": ["gentleman", "man", "male","guy","he","him","men"],
               "female": ["female", "woman", "girl","women","she","her"]}

gender = re.findall(gender_dict, df.Description)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-51e811165cef> in <module>
#       2                "female": ["female", "woman", "girl","women","she","her"]}
#       3
# ----> 4 gender = re.findall(gender_dict, df.Description)
#
# ~\AppData\Local\Programs\Python\Python38\lib\re.py in findall(pattern, string, flags)
#     239
#     240     Empty matches are included in the result."""
# --> 241     return _compile(pattern, flags).findall(string)
#     242
#     243 def finditer(pattern, string, flags=0):
#
# ~\AppData\Local\Programs\Python\Python38\lib\re.py in _compile(pattern, flags)
#     292         flags = flags.value
#     293     try:
# --> 294         return _cache[type(pattern), pattern, flags]
#     295     except KeyError:
#     296         pass
#
# TypeError: unhashable type: 'dict'
